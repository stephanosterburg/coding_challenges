# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Intro" data-toc-modified-id="Intro-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Intro</a></span></li><li><span><a href="#Load-the-necessary-libraries" data-toc-modified-id="Load-the-necessary-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load the necessary libraries</a></span></li><li><span><a href="#Inspection-+-Cleaning" data-toc-modified-id="Inspection-+-Cleaning-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Inspection + Cleaning</a></span></li><li><span><a href="#What-type-data-do-we-have" data-toc-modified-id="What-type-data-do-we-have-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>What type data do we have</a></span></li><li><span><a href="#Data-Types" data-toc-modified-id="Data-Types-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data Types</a></span></li><li><span><a href="#NaN" data-toc-modified-id="NaN-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>NaN</a></span></li><li><span><a href="#Float-Values" data-toc-modified-id="Float-Values-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Float Values</a></span></li><li><span><a href="#Date" data-toc-modified-id="Date-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Date</a></span></li><li><span><a href="#Duplicates" data-toc-modified-id="Duplicates-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Duplicates</a></span><ul class="toc-item"><li><span><a href="#Investigating-duplicate-timestamps" data-toc-modified-id="Investigating-duplicate-timestamps-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Investigating duplicate timestamps</a></span></li><li><span><a href="#Lets-pick-us-a-specific-timestamp-and-check-for-it." data-toc-modified-id="Lets-pick-us-a-specific-timestamp-and-check-for-it.-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Lets pick us a specific timestamp and check for it.</a></span></li></ul></li><li><span><a href="#Check-dataset" data-toc-modified-id="Check-dataset-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Check dataset</a></span></li><li><span><a href="#How-many-times-is-a-port-listed?" data-toc-modified-id="How-many-times-is-a-port-listed?-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>How many times is a port listed?</a></span></li><li><span><a href="#Create-a-simplified-dataset" data-toc-modified-id="Create-a-simplified-dataset-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Create a simplified dataset</a></span></li><li><span><a href="#How-balanced-is-our-data?" data-toc-modified-id="How-balanced-is-our-data?-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>How balanced is our data?</a></span></li><li><span><a href="#How-connected-is-the-Port-of-Savannah?" data-toc-modified-id="How-connected-is-the-Port-of-Savannah?-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>How connected is the Port of Savannah?</a></span></li><li><span><a href="#How-&quot;connected&quot;-are-the-ports-to-each-other-(based-on-2017)" data-toc-modified-id="How-&quot;connected&quot;-are-the-ports-to-each-other-(based-on-2017)-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>How "connected" are the ports to each other (based on 2017)</a></span><ul class="toc-item"><li><span><a href="#Create-nodes-for-Chord-Diagram" data-toc-modified-id="Create-nodes-for-Chord-Diagram-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>Create nodes for Chord Diagram</a></span></li><li><span><a href="#Create-links-for-Chord-Diagram" data-toc-modified-id="Create-links-for-Chord-Diagram-15.2"><span class="toc-item-num">15.2&nbsp;&nbsp;</span>Create links for Chord Diagram</a></span><ul class="toc-item"><li><span><a href="#Convert-the-ports-to-the-index-numbers-we-have-in-nodes" data-toc-modified-id="Convert-the-ports-to-the-index-numbers-we-have-in-nodes-15.2.1"><span class="toc-item-num">15.2.1&nbsp;&nbsp;</span>Convert the ports to the index numbers we have in nodes</a></span></li></ul></li><li><span><a href="#Checking-if-everything-is-correct" data-toc-modified-id="Checking-if-everything-is-correct-15.3"><span class="toc-item-num">15.3&nbsp;&nbsp;</span>Checking if everything is correct</a></span></li><li><span><a href="#Chord-Graph" data-toc-modified-id="Chord-Graph-15.4"><span class="toc-item-num">15.4&nbsp;&nbsp;</span>Chord Graph</a></span></li><li><span><a href="#How-connected-is-Port-of-Savannah" data-toc-modified-id="How-connected-is-Port-of-Savannah-15.5"><span class="toc-item-num">15.5&nbsp;&nbsp;</span>How connected is Port of Savannah</a></span></li><li><span><a href="#Plot-the-connectivity-of-the-Port-of-Savannah" data-toc-modified-id="Plot-the-connectivity-of-the-Port-of-Savannah-15.6"><span class="toc-item-num">15.6&nbsp;&nbsp;</span>Plot the connectivity of the Port of Savannah</a></span></li></ul></li><li><span><a href="#How-many-ports-does-a-vessel-sail-into?" data-toc-modified-id="How-many-ports-does-a-vessel-sail-into?-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>How many ports does a vessel sail into?</a></span></li><li><span><a href="#Show-how-frequent-a-port-is-&quot;visited&quot;-during-a-day,-month,-year." data-toc-modified-id="Show-how-frequent-a-port-is-&quot;visited&quot;-during-a-day,-month,-year.-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Show how frequent a port is "visited" during a day, month, year.</a></span></li><li><span><a href="#eta_tpye:-past-vs-future" data-toc-modified-id="eta_tpye:-past-vs-future-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>eta_tpye: past vs future</a></span></li><li><span><a href="#Time-Series-Analyse-with-Prophet" data-toc-modified-id="Time-Series-Analyse-with-Prophet-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Time Series Analyse with Prophet</a></span><ul class="toc-item"><li><span><a href="#How-late-or-early-arrives-a-vessel?" data-toc-modified-id="How-late-or-early-arrives-a-vessel?-19.1"><span class="toc-item-num">19.1&nbsp;&nbsp;</span>How late or early arrives a vessel?</a></span></li><li><span><a href="#Using-fbprophet-to-predict-the-arrival-in-the-future" data-toc-modified-id="Using-fbprophet-to-predict-the-arrival-in-the-future-19.2"><span class="toc-item-num">19.2&nbsp;&nbsp;</span>Using fbprophet to predict the arrival in the future</a></span></li></ul></li></ul></div>

# %% [markdown]
# ---
# ## Intro
#
# * Below there are three parts for explore the given dataset:
#     * Inspecting the data and cleaning where it is needed
#     * I am going to use `fbprophet` to do some timeseries analyse towards to end.
#     * I will use `holoview` (chord graph and sankey) to display how the ports are connected to each other. Also to see how the Port of Savannah is connected in the year 2019.
#
# ![holoview.png](holoview.png)
#
#     Note: Unfortunately, bokeh doesn't save correctly, so I am using matplotlib instead. Bokeh would have given us an interactive display where we could "zoom" in and "hover" over the graph to get more detailed informations.

# %% [markdown]
# ## Load the necessary libraries

# %%
import math
import pandas as pd
import numpy as np

from fbprophet import Prophet as proph

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import seaborn as sns
# %matplotlib inline

import holoviews as hv
from holoviews import opts, dim
from bokeh.sampledata.les_mis import data

hv.extension('matplotlib')
hv.output(fig='svg', size=500)

import warnings
warnings.filterwarnings('ignore')
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# ## Inspection + Cleaning

# %%
df = pd.read_csv('analyst_data_challenge.csv')
df.head()
# Out:
#    container_trip_id                milestone_type             milestone_time  \
# 0                1.0     vessel_arrive_destination  2017-11-02 16:48:00+00:00
# 1                1.0  vessel_discharge_destination  2017-11-04 07:12:00+00:00
# 2                2.0            vessel_load_origin  2017-10-23 01:18:00+00:00
# 3                2.0          vessel_depart_origin  2017-10-23 06:40:00+00:00
# 4                2.0     vessel_arrive_destination  2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode              date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX  2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX  2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA  2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA  2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX  2017-11-08 01:27:00+00:00
#
#   ocean_carrier_code  port_call_id  vessel_id  vessel_name status_code  \
# 0               EGLV           NaN      10034  CAPE KORTIA          VA
# 1               EGLV           NaN      10034  CAPE KORTIA          UV
# 2               EGLV           NaN       7518  EVER LIVELY          AE
# 3               EGLV           NaN       7518  EVER LIVELY          VD
# 4               EGLV           NaN       7518  EVER LIVELY          VA
#
#   eta_type planned_discharge_location planned_discharge_unlocode  \
# 0     past    LOS ANGELES, CALIFORNIA                      USLAX
# 1     past    LOS ANGELES, CALIFORNIA                      USLAX
# 2   future    LOS ANGELES, CALIFORNIA                      USLAX
# 3   future    LOS ANGELES, CALIFORNIA                      USLAX
# 4     past    LOS ANGELES, CALIFORNIA                      USLAX
#
#                discharge_eta
# 0  2017-11-04 07:12:00+00:00
# 1  2017-11-04 07:12:00+00:00
# 2  2017-11-07 01:00:00+00:00
# 3  2017-11-07 01:00:00+00:00
# 4  2017-11-08 00:07:00+00:00

# %%
print('Number of Features: {} \nNumber of Observations: {}'.format(df.shape[1], df.shape[0]))
# Out:
# Number of Features: 15
# Number of Observations: 22794

# %% [markdown]
# ## What type data do we have

# %%
df.columns
# Out:
# Index(['container_trip_id', 'milestone_type', 'milestone_time',
#        'milestone_location', 'milestone_unlocode', 'date_received',
#        'ocean_carrier_code', 'port_call_id', 'vessel_id', 'vessel_name',
#        'status_code', 'eta_type', 'planned_discharge_location',
#        'planned_discharge_unlocode', 'discharge_eta'],
#       dtype='object')

# %% [markdown]
# The column definitions are as follows:
#
# + __Container_trip_id__: An integer that uniquely identifies a single container shipment and all the milestones associated with that shipment
# + __Milestone_type__: A string that identifies key events in the shipment life cycle
# + __Milestone_time__: A datetime that indicates the date and time at which the above milestone occurred
# + __Milestone_location__: A string that indicates the name of the location at which the above milestone occurred
# + __Milestone_unlocode__: A 5-character string that is used as a standardized location code (one-to-one with milestone_location)
# + __Date_received__: A datetime that indicates when the milestone update was received (distinct from when the milestone actually occurred)
# + __Ocean_carrier_code__: A 4-character string that uniquely identifies the ocean carrier that is responsible for the shipment
# + __Port_call_id__: An integer that uniquely identifies a vessel stop at a port
# + __Vessel_id__: An integer that uniquely identifies the vessel associated with the current milestone (although sometimes the carrier attaches the incorrect vessel or attaches a future vessel to the current milestone)
# + __Vessel_name__: A string that indicates the name of the vessel associated with the current milestone
# + __Status_code__: A raw code associated with the current milestone
# + __Eta_type__: Either ‘future’ or ‘past’ - indicating whether the discharge_eta (see below) is for a milestone that has already occurred or has yet to occur
# + __Planned_discharge_location__: A string that indicates the name of the location at which the container is scheduled to be discharged (aka unloaded from the vessel at the final port in the container’s journey)
# + __Planned_discharge_unlocode__: A 5-character string that is used as a standardized location code (one-to-one with planned_discharge_location)
# + __Discharge_eta__: A datetime that indicates when the carrier thinks the container will be discharged at the final port in its journey

# %% [markdown]
# ---
# ## Data Types
#
# Making sure that the data types are set correctly, as well as checking for null values and more...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22794 entries, 0 to 22793
# Data columns (total 15 columns):
# container_trip_id             22794 non-null float64
# milestone_type                22794 non-null object
# milestone_time                22794 non-null object
# milestone_location            22794 non-null object
# milestone_unlocode            22794 non-null object
# date_received                 22794 non-null object
# ocean_carrier_code            22788 non-null object
# port_call_id                  15225 non-null float64
# vessel_id                     22794 non-null int64
# vessel_name                   22794 non-null object
# status_code                   22794 non-null object
# eta_type                      22033 non-null object
# planned_discharge_location    22794 non-null object
# planned_discharge_unlocode    22794 non-null object
# discharge_eta                 22553 non-null object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 2.6+ MB

# %% [markdown]
# Some of the data types seem to be wrong, i.e.
# + `container_trip_id` most likely should be not of type `float`
# + `milestone_time` should be of type `datetime`.

# %% [markdown]
# ## NaN
#
# Let us first deal with NULL values.

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isna().sum()
# Out:
# container_trip_id                0
# milestone_type                   0
# milestone_time                   0
# milestone_location               0
# milestone_unlocode               0
# date_received                    0
# ocean_carrier_code               6
# port_call_id                  7569
# vessel_id                        0
# vessel_name                      0
# status_code                      0
# eta_type                       761
# planned_discharge_location       0
# planned_discharge_unlocode       0
# discharge_eta                  241
# dtype: int64

# %% [markdown]
# We have a few features which have no data:
# - `port_call_id`: Considering the size of our dataset and especially, such an important one, is missing too much data (~30%).
# - `eta_type`: With about 3% having no data, we can ignore them and remove the missing entries in order to build our model.
# - `discharge_eta`: With "only" 241 missing data (>1%) we might be able to engineer them, but needs further investigation. Or if they aline with the missing data we are seeing at the `eta_type`, ignore them.
# - `ocean_carrier_code`: We are missing 6 out of 22794. Even though it is an important information to have, to build a model we can neglect the missing entries.

# %% [markdown]
# ## Float Values
#
# We have `container_trip_id` and `port_call_id` which are of type float. Are float numbers like `1.5` are used here as ID's?

# %%
def check_feature(feature):
    '''
    Iterate over all values in a given column and 
    check if float value has a number higher then zero behind the comma. 
    
    :param feature: column name
    :return: 
    '''
    for idx, row in df.iterrows():
        # Check if given element is NaN or not
        if pd.isnull(row[feature]):
            pass
        else:
            # Get the digit after the comma
            digit = str(row[feature]).split('.')[1]
            # Check if digit is higher then zero
            if int(digit) > 0:
                print(n)

    # The end.
    print('Done')

# %%
df['container_trip_id']
# Out:
# 0           1.0
# 1           1.0
# 2           2.0
# 3           2.0
# 4           2.0
#           ...
# 22789    4611.0
# 22790    4611.0
# 22791    4612.0
# 22792    4613.0
# 22793    4613.0
# Name: container_trip_id, Length: 22794, dtype: float64

# %%
check_feature('container_trip_id')
# Out:
# Done

# %%
df['port_call_id']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 22789     398019.0
# 22790     398019.0
# 22791    1225671.0
# 22792     391909.0
# 22793     391909.0
# Name: port_call_id, Length: 22794, dtype: float64

# %%
check_feature('port_call_id')
# Out:
# Done

# %% [markdown]
# We have no values which are for example 1.5 as an ID, so we can safely convert the two features to type `INT`.

# %%
df['container_trip_id'] = df['container_trip_id'].astype(int)

# %% [markdown]
# Before we convert `port_call_id` to dtype `int`, we need to deal with the `NaN` values. Because of the high number of missing values we shall set them to a special number, i.e. 999999999.

# %%
# Just making sure that 999999999 is not already taken and set it in the following cell.
df['port_call_id'].max()
# Out:
# 1371616.0

# %%
df['port_call_id'] = df['port_call_id'].replace(np.nan, 999999999).astype(int)

# %% [markdown]
# ## Date
#
# We have several features, `milestone_time`, `date_received` and `discharge_eta`, which represent date/time and should be set as such.

# %%
df['milestone_time'] = pd.to_datetime(df['milestone_time'])
df['date_received'] = pd.to_datetime(df['date_received'])
df['discharge_eta'] = pd.to_datetime(df['discharge_eta'])

# %% [markdown]
# ## Duplicates
#
# We want to check for duplicates in our dataset and determine what to do with it.

# %%
print(any(df['milestone_time'].duplicated()))
# Out:
# True

# %%
dup_df = df['milestone_time'].duplicated()
pd.value_counts(dup_df.values, sort=False)
# Out:
# False    20012
# True      2782
# dtype: int64

# %% [markdown]
# A simple check on the `milestone_time` feature tells us that we have 2782 duplicates. But what does that actually mean? Are these real duplicates or is it actually ok to have the same `milestone_time`?

# %% [markdown]
# ### Investigating duplicate timestamps
#
#  The quetion here is, whether or not we have duplicate data. If that is the case, what shall we do about it?

# %%
# Find element index in pandas series
dup_df[dup_df == True]
# Out:
# 7        True
# 9        True
# 195      True
# 245      True
# 328      True
#          ...
# 22779    True
# 22781    True
# 22783    True
# 22785    True
# 22793    True
# Name: milestone_time, Length: 2782, dtype: bool

# %% [markdown]
# We have 2782 elements deemed as duplicates. Whether that is correct needs to be further investigated.

# %%
df.iloc[[22779,22781,22783,22785],]
# Out:
#        container_trip_id               milestone_type  \
# 22779               4606         vessel_depart_origin
# 22781               4607         vessel_depart_origin
# 22783               4608  vessel_arrive_transshipment
# 22785               4609    vessel_arrive_destination
#
#                  milestone_time          milestone_location  \
# 22779 2019-07-20 20:33:00+00:00         BALTIMORE, MARYLAND
# 22781 2019-07-19 12:00:00+00:00      LONG BEACH, CALIFORNIA
# 22783 2019-07-19 19:09:00+00:00             SHANGHAI, CHINA
# 22785 2019-07-19 22:57:00+00:00  CHARLESTON, SOUTH CAROLINA
#
#       milestone_unlocode             date_received ocean_carrier_code  \
# 22779              USBAL 2019-07-20 21:21:00+00:00               SUDU
# 22781              USLGB 2019-07-20 03:27:55+00:00               WHLC
# 22783              CNSHA 2019-07-19 20:32:00+00:00               SUDU
# 22785              USCHS 2019-07-20 01:44:00+00:00               MAEU
#
#        port_call_id  vessel_id         vessel_name status_code eta_type  \
# 22779        393632       7779  SPIRIT OF AUCKLAND          VD   future
# 22781       1361894      14401        KOTA PERWIRA          VD   future
# 22783       1239033       2238          SANTA INES          VA      NaN
# 22785        392033         64            PARSIFAL          VA     past
#
#        planned_discharge_location planned_discharge_unlocode  \
# 22779      BUENAVENTURA, COLOMBIA                      COBUN
# 22781            TAICHUNG, TAIWAN                      TWTXG
# 22783        NANJING LUKOU, CHINA                      CNNKG
# 22785  CHARLESTON, SOUTH CAROLINA                      USCHS
#
#                   discharge_eta  year  day        date  timedelta_in_min
# 22779 2019-08-04 08:00:00+00:00  2019  201  2019-07-20                48
# 22781 2019-08-22 05:00:00+00:00  2019  200  2019-07-19               927
# 22783                       NaT  2019  200  2019-07-19                83
# 22785 2019-07-19 08:30:00+00:00  2019  200  2019-07-19               167

# %% [markdown]
# The day is the same between the last three row but the time differs.

# %% [markdown]
# ### Lets pick us a specific timestamp and check for it.

# %%
timestamp = df['milestone_time'].iloc[195]
ts_df = df[df['milestone_time'] == timestamp]
ts_df.head()
# Out:
#      container_trip_id             milestone_type            milestone_time  \
# 90                  19  vessel_arrive_destination 2017-12-22 04:00:00+00:00
# 195                 42  vessel_arrive_destination 2017-12-22 04:00:00+00:00
#
#        milestone_location milestone_unlocode             date_received  \
# 90   BREMERHAVEN, GERMANY              DEBRV 2017-12-23 02:28:00+00:00
# 195    BUSAN, SOUTH KOREA              KRPUS 2017-12-22 13:00:15+00:00
#
#     ocean_carrier_code  port_call_id  vessel_id  vessel_name status_code  \
# 90                CMDU     999999999       8069  OOCL EUROPE          VA
# 195               MSCU     999999999       9621    MSC BERYL          VA
#
#     eta_type planned_discharge_location planned_discharge_unlocode  \
# 90      past       BREMERHAVEN, GERMANY                      DEBRV
# 195     past         BUSAN, SOUTH KOREA                      KRPUS
#
#                 discharge_eta  year  day        date  timedelta_in_min
# 90  2017-12-22 11:00:00+00:00  2017  356  2017-12-22              1348
# 195 2017-12-22 10:08:00+00:00  2017  356  2017-12-22               540

# %% [markdown]
# `milestone_time` can be the same as long the `milestone_location` is different, i.e. index `90` and `195` have the same `milestone_time` but have a different `milestone_location`.
#
# __NOTE__: We still want to make sure that we don't have duplicates in our data, but for now we will leave it as is.

# %% [markdown]
# ## Check dataset
#
# Just making sure that everything now is cleaned up and now usable.
#
# __Note__: We still need to figure out what we want/need to do with our custom `port_call_id == 999999999` or if we can just ignore it at all.

# %%
df.head()
# Out:
#    container_trip_id                milestone_type            milestone_time  \
# 0                  1     vessel_arrive_destination 2017-11-02 16:48:00+00:00
# 1                  1  vessel_discharge_destination 2017-11-04 07:12:00+00:00
# 2                  2            vessel_load_origin 2017-10-23 01:18:00+00:00
# 3                  2          vessel_depart_origin 2017-10-23 06:40:00+00:00
# 4                  2     vessel_arrive_destination 2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode             date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA 2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA 2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX 2017-11-08 01:27:00+00:00
#
#   ocean_carrier_code  port_call_id  vessel_id  vessel_name status_code  \
# 0               EGLV     999999999      10034  CAPE KORTIA          VA
# 1               EGLV     999999999      10034  CAPE KORTIA          UV
# 2               EGLV     999999999       7518  EVER LIVELY          AE
# 3               EGLV     999999999       7518  EVER LIVELY          VD
# 4               EGLV     999999999       7518  EVER LIVELY          VA
#
#   eta_type planned_discharge_location planned_discharge_unlocode  \
# 0     past    LOS ANGELES, CALIFORNIA                      USLAX
# 1     past    LOS ANGELES, CALIFORNIA                      USLAX
# 2   future    LOS ANGELES, CALIFORNIA                      USLAX
# 3   future    LOS ANGELES, CALIFORNIA                      USLAX
# 4     past    LOS ANGELES, CALIFORNIA                      USLAX
#
#               discharge_eta
# 0 2017-11-04 07:12:00+00:00
# 1 2017-11-04 07:12:00+00:00
# 2 2017-11-07 01:00:00+00:00
# 3 2017-11-07 01:00:00+00:00
# 4 2017-11-08 00:07:00+00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22794 entries, 0 to 22793
# Data columns (total 15 columns):
# container_trip_id             22794 non-null int64
# milestone_type                22794 non-null object
# milestone_time                22794 non-null datetime64[ns, UTC]
# milestone_location            22794 non-null object
# milestone_unlocode            22794 non-null object
# date_received                 22794 non-null datetime64[ns, UTC]
# ocean_carrier_code            22788 non-null object
# port_call_id                  22794 non-null int64
# vessel_id                     22794 non-null int64
# vessel_name                   22794 non-null object
# status_code                   22794 non-null object
# eta_type                      22033 non-null object
# planned_discharge_location    22794 non-null object
# planned_discharge_unlocode    22794 non-null object
# discharge_eta                 22553 non-null datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](3), int64(3), object(9)
# memory usage: 2.6+ MB

# %% [markdown]
# ## How many times is a port listed?

# %%
pd.value_counts(df['milestone_location'].values, sort=True)
# Out:
# SAVANNAH, GEORGIA       1352
# SINGAPORE, SINGAPORE    1245
# BUSAN, SOUTH KOREA      1054
# SHANGHAI, CHINA         1035
# HONG KONG, HONG KONG     864
#                         ...
# PORTLAND, OREGON           1
# TARRAGONA, SPAIN           1
# YANGON, MYANMAR            1
# SHATIAN, CHINA             1
# SAGUNTO, SPAIN             1
# Length: 310, dtype: int64

# %% [markdown]
# Based on the data given the top 5 ports are:
# - SAVANNAH, GEORGIA
# - SINGAPORE, SINGAPORE
# - BUSAN, SOUTH KOREA
# - SHANGHAI, CHINA
# - HONG KONG, HONG KONG
#
# We seem to have an inbalance in our dataset.

# %% [markdown]
# ## Create a simplified dataset
#
# Lets focus on the ports and create from `milestone_time` a `year` and `day` feature.

# %%
# Create a stripped down dataset with only time and port features
milestone_df = df.loc[:, ('milestone_time', 'milestone_unlocode')]
milestone_df.dropna(how='any', inplace=True)

# Convert milestone_time into year and day
milestone_df['year'] = milestone_df['milestone_time'].dt.year
milestone_df['day'] = milestone_df['milestone_time'].dt.dayofyear
milestone_df.drop(['milestone_time'], axis=1, inplace=True)

milestone_df.head()
# Out:
#   milestone_unlocode  year  day
# 0              USLAX  2017  306
# 1              USLAX  2017  308
# 2              CNSHA  2017  296
# 3              CNSHA  2017  296
# 4              USLAX  2017  311

# %% [markdown]
# ## How balanced is our data?
#
# _(Note: This check should come at an earlier stage.)_

# %%
years = milestone_df['year'].unique()
for year in sorted(years):
    print('Year: {} - Number: {}'.format(year, sum((milestone_df['year'] == year))))
# Out:
# Year: 2001 - Number: 1
# Year: 2008 - Number: 7
# Year: 2012 - Number: 5
# Year: 2013 - Number: 10
# Year: 2014 - Number: 9
# Year: 2015 - Number: 35
# Year: 2016 - Number: 18
# Year: 2017 - Number: 1941
# Year: 2018 - Number: 7719
# Year: 2019 - Number: 13049

# %% [markdown]
# We have unfortunately a very unbalanced dataset. Not suprising that we see ports which are only listed once, considering the inbalance in our data. Therefore let us focus on the year 2017 a bit later.

# %%
def plot_by_year(year):
    '''
    How many times is a port listed in a given year and create a countplot.
    
    :param year: year
    :return: countplot
    '''
    
    # Set plot size
    plt.figure(figsize=(16, 8))
    
    # Define countplot
    chart = sns.countplot(
        data=milestone_df[milestone_df['year'] == year],
        x='milestone_unlocode',
        palette='Set1'
    )
    chart.set_xticklabels(chart.get_xticklabels(), 
                          rotation=65, 
                          horizontalalignment='right',
                          fontweight='light',
                          fontsize='xx-small');

# %%
plot_by_year(2017)

# %% [markdown]
# For the year __2017__, `Savannah, Georgia` is the leading port by about 25% (based on the graph above).

# %%
plot_by_year(2018)

# %%
plot_by_year(2019)

# %% [markdown]
# With the amount of ports listed in 2018 and 2019 it is not particular great to read the ports, but nice to look at the graph itself.

# %% [markdown]
# ## How connected is the Port of Savannah?
#
# Based on `eta_type`, how many vessels go to which port in the future?

# %%
# Get Port of Savannah
sav_df = df[df['milestone_unlocode'] == 'USSAV'].reset_index(drop=True)

# Split milestone_time into year and day
sav_df['year'] = sav_df['milestone_time'].dt.year
sav_df['day'] = sav_df['milestone_time'].dt.dayofyear

# Drop not needed features
features = ['container_trip_id', 'milestone_type', 'milestone_time', 'milestone_location', 
            'date_received', 'ocean_carrier_code', 'port_call_id', 'vessel_id', 'vessel_name',
            'status_code', 'planned_discharge_location', 'discharge_eta']
sav_df.drop(features, axis=1, inplace=True)

# Drop all eta_type == past
sav_df.drop(sav_df[sav_df.eta_type == 'past'].index, inplace=True)

sav_df.head()
# Out:
#   milestone_unlocode eta_type planned_discharge_unlocode  year  day
# 0              USSAV   future                      EGALY  2017  240
# 1              USSAV   future                      EGALY  2017  240
# 2              USSAV   future                      DOCAU  2017  357
# 3              USSAV   future                      DOCAU  2017  358
# 4              USSAV   future                      DEBRV  2017  338

# %%
data = pd.value_counts(sav_df['planned_discharge_unlocode'].values, sort=True)
data.head(25)
# Out:
# CNTAO    85
# KRPUS    77
# CNSHA    74
# CNTXG    53
# CNCGU    48
# INNSA    48
# IDJKT    45
# ITLIV    41
# DEBRV    30
# CNNGB    28
# IDSUB    26
# INMUN    26
# RULED    24
# ITNAP    24
# NLRTM    24
# TWKHH    22
# INMAA    22
# TRISK    20
# COBUN    20
# CNXMN    19
# SADMM    18
# CRPMN    18
# INHZA    18
# CNHUA    18
# ESVLC    17
# dtype: int64

# %% [markdown]
# These are the top 25 ports which are highly connected to the Port of Savannah based on number of planned discharge locations in the future (eta_type).

# %% [markdown]
# ## How "connected" are the ports to each other (based on 2017)
#
# We want to look at the relationship between `milestone_location` and `planned_discharge_location` based on `eta_type` if it is set to `future`.

# %%
# Create a stripped down dataset with only time and port features
year_df = df.loc[:, ('milestone_time', 'milestone_unlocode', 'milestone_location', 'eta_type', 
                     'planned_discharge_location', 'planned_discharge_unlocode')]
year_df.dropna(how='any', inplace=True)

# Convert milestone_time into year and day
year_df['year'] = year_df['milestone_time'].dt.year
year_df['day'] = year_df['milestone_time'].dt.dayofyear

# Drop feature 'milestone_time' and 'eta_type' == past
year_df.drop(['milestone_time'], axis=1, inplace=True)
year_df.drop(year_df[year_df['eta_type'] == 'past'].index, inplace=True)

# Get only year 2017
year_df = year_df[year_df['year'] == 2017].reset_index(drop=True)

year_df.head()
# Out:
#   milestone_unlocode milestone_location eta_type planned_discharge_location  \
# 0              CNSHA    SHANGHAI, CHINA   future    LOS ANGELES, CALIFORNIA
# 1              CNSHA    SHANGHAI, CHINA   future    LOS ANGELES, CALIFORNIA
# 2              CNNGB      NINGBO, CHINA   future              NINGBO, CHINA
# 3              CNNGB      NINGBO, CHINA   future              NINGBO, CHINA
# 4              USMOB    MOBILE, ALABAMA   future    CHANGSHU JIANGSU, CHINA
#
#   planned_discharge_unlocode  year  day
# 0                      USLAX  2017  296
# 1                      USLAX  2017  296
# 2                      CNNGB  2017  245
# 3                      CNNGB  2017  245
# 4                      CNCGU  2017  259

# %% [markdown]
# ### Create nodes for Chord Diagram

# %%
ports = df['milestone_unlocode'].unique()
ports.sort()
nodes = pd.DataFrame({'ports': ports})
nodes['index'] = nodes.index

# %%
t = nodes['index']
nodes.drop(labels=['index'], axis=1, inplace = True)
nodes.insert(0, 'index', t)
nodes.head()
# Out:
#    index  ports
# 0      0  AEAUH
# 1      1  AEJEA
# 2      2  AEKLF
# 3      3  AOLAD
# 4      4  ARBUE

# %% [markdown]
# ### Create links for Chord Diagram

# %%
links = year_df.loc[:, ('milestone_unlocode', 'planned_discharge_unlocode')]
links
# Out:
#      milestone_unlocode planned_discharge_unlocode
# 0                 CNSHA                      USLAX
# 1                 CNSHA                      USLAX
# 2                 CNNGB                      CNNGB
# 3                 CNNGB                      CNNGB
# 4                 USMOB                      CNCGU
# ...                 ...                        ...
# 1156              DEHAM                      RULED
# 1157              RULED                      RULED
# 1158              KRPUS                      CAVAN
# 1159              CAVAN                      CAVAN
# 1160              USTIW                      USTIW
#
# [1161 rows x 2 columns]

# %% [markdown]
# #### Convert the ports to the index numbers we have in nodes

# %%
test = nodes.set_index('index').T.to_dict('list')

# %%
for key, value in test.items():
    links['milestone_unlocode'].mask(links['milestone_unlocode'] == value[0], key, inplace=True)
    links['planned_discharge_unlocode'].mask(links['planned_discharge_unlocode'] == value[0], key, inplace=True)

links.rename(columns={'milestone_unlocode': 'source', 'planned_discharge_unlocode': 'target'}, inplace=True)
links
# Out:
#      source target
# 0        52    282
# 1        52    282
# 2        47     47
# 3        47     47
# 4       285     42
# ...     ...    ...
# 1156     73    231
# 1157    231    231
# 1158    176     32
# 1159     32     32
# 1160    297    297
#
# [1161 rows x 2 columns]

# %% [markdown]
# ### Checking if everything is correct
#
# We want to see only numbers in the source and target column. If there are other listed, we might want to drop these entries (rows).

# %%
links['source'].unique()
# Out:
# array([52, 47, 285, 239, 294, 85, 282, 289, 281, 118, 176, 196, 284, 139,
#        283, 53, 95, 12, 276, 234, 190, 277, 1, 288, 60, 77, 208, 275, 297,
#        56, 268, 156, 138, 233, 179, 207, 90, 28, 57, 86, 210, 274, 290,
#        89, 134, 126, 184, 149, 65, 148, 201, 63, 147, 143, 106, 286, 69,
#        93, 15, 124, 132, 174, 194, 116, 66, 73, 231, 32], dtype=object)

# %%
links['target'].unique()
# Out:
# array([282, 47, 42, 49, 268, 82, 133, 'CNYUY', 48, 139, 45, 159, 56, 57,
#        77, 72, 246, 60, 'CNCKG', 160, 'CNCLJ', 61, 176, 150, 79, 110, 166,
#        190, 134, 196, 252, 102, 32, 'CNCSX', 118, 10, 26, 231, 52, 174, 0,
#        201, 129, 143, 65, 308, 138, 213, 124, 140, 12, 95, 37, 169, 109,
#        11, 39, 132, 142, 270, 128, 71, 136, 126, 149, 43, 148, 46,
#        'CNZHE', 53, 274, 111, 80, 253, 106, 'CNJAX', 165, 69, 168, 171,
#        41, 130, 64, 93, 15, 276, 116, 289, 297], dtype=object)

# %% [markdown]
# __Note__: We have still some string values here.

# %%
for i in links['target'].unique():
    if isinstance(i, str):
        print(len(links[links['target'] == i]))
# Out:
# 2
# 16
# 6
# 3
# 4
# 6

# %% [markdown]
# Let us remove the non-existing ports represented as string from the links.

# %%
for i in links['target'].unique():
    if isinstance(i, str):
        links.drop(links[links['target'] == i].index, inplace=True)

links.head()
# Out:
#   source target
# 0     52    282
# 1     52    282
# 2     47     47
# 3     47     47
# 4    285     42

# %% [markdown]
# ### Chord Graph
#
# Display the interconnectivity of the port in the year 2017.
#
# __Note__: The below graph is displayed as matlibplot instead of bokeh. Preferably I wanted to use the bokeh representation, but had issues with not displaying when opening the notebook.

# %%
# For holoview to work, we add node labels and other information 
# we construct a Dataset with a key dimension of node indices.
nodes = hv.Dataset(nodes, 'index')

# %%
chord = hv.Chord((links, nodes)).select(value=(5, None))
chord.opts(
    opts.Chord(cmap='Category20', 
               edge_cmap='Category20', 
               edge_color=dim('source').str(), 
               labels='ports', 
               node_color=dim('index').str()))
# Out:
# :Chord   [source,target]

# %% [markdown]
# We can see on the right side of the graph `USSAV (Port of Savannah)` and see how connected the port is to the rest of the world in 2017.

# %% [markdown]
# ### How connected is Port of Savannah
#
# Create the links for the Port of Savannah only

# %%
sav_links = year_df.loc[:, ('milestone_location', 'planned_discharge_location')] 
sav_links = sav_links.drop(sav_links[sav_links['milestone_location'] != 'SAVANNAH, GEORGIA'].index)

# %% [markdown]
# Create a dataframe with source port (`USSAV`) and its `planned_discharge_unlocode` as `target` and the number of times they appear.

# %%
# Count values in sav_links
result = sav_links.apply(pd.value_counts).fillna(0)
# Convert index t ocolumn
result.reset_index(level=0, inplace=True)
# Drop everything which is not USSAV
result = result[result['index'] != 'SAVANNAH, GEORGIA']
result.drop(['milestone_location'], axis=1, inplace=True)
# Rename columns
result.rename(columns={'index': 'target', 'planned_discharge_location': 'value'}, inplace=True)
result['source'] = 'SAVANNAH, GEORGIA'
# Reorder columns
tmp = result['source']
result.drop(labels=['source'], axis=1, inplace = True)
result.insert(0, 'source', tmp)

result.head()
# Out:
#               source                           target  value
# 0  SAVANNAH, GEORGIA  ABU DHABI, UNITED ARAB EMIRATES    2.0
# 1  SAVANNAH, GEORGIA                   ALGER, ALGERIA    2.0
# 2  SAVANNAH, GEORGIA               ANTWERPEN, BELGIUM    2.0
# 3  SAVANNAH, GEORGIA             BREMERHAVEN, GERMANY    8.0
# 4  SAVANNAH, GEORGIA               BUSAN, SOUTH KOREA   10.0

# %%
print('Number of planned discharge ports: {}'.format(result.shape[0]))
# Out:
# Number of planned discharge ports: 42

# %% [markdown]
# ### Plot the connectivity of the Port of Savannah

# %%
sankey = hv.Sankey(result, label='Port of Savannah')
sankey.opts(label_position='left', edge_color='target', node_color='index', cmap='tab20')
# Out:
# :Sankey   [source,target]   (value)

# %% [markdown]
# The `Port of Savannah` has `161` vessels leaving its port to `42` ports. The top 3 port are `CNTXG`, `ITLIV` and `KRPUS`.
#
# __Note__: Should use the actual port names instead their code.

# %% [markdown]
# ## How many ports does a vessel sail into?

# %%
vessels = df['vessel_id'].unique()
print('Number of vessels: {}'.format(vessels.shape[0]))
# Out:
# Number of vessels: 2076

# %% [markdown]
# We have over 2000 vessels listed in our data. Let us focus again only on the year 2017 and pick a vessel from that year.

# %%
df.head()
# Out:
#    container_trip_id                milestone_type            milestone_time  \
# 0                  1     vessel_arrive_destination 2017-11-02 16:48:00+00:00
# 1                  1  vessel_discharge_destination 2017-11-04 07:12:00+00:00
# 2                  2            vessel_load_origin 2017-10-23 01:18:00+00:00
# 3                  2          vessel_depart_origin 2017-10-23 06:40:00+00:00
# 4                  2     vessel_arrive_destination 2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode             date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA 2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA 2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX 2017-11-08 01:27:00+00:00
#
#   ocean_carrier_code  port_call_id  vessel_id  vessel_name status_code  \
# 0               EGLV     999999999      10034  CAPE KORTIA          VA
# 1               EGLV     999999999      10034  CAPE KORTIA          UV
# 2               EGLV     999999999       7518  EVER LIVELY          AE
# 3               EGLV     999999999       7518  EVER LIVELY          VD
# 4               EGLV     999999999       7518  EVER LIVELY          VA
#
#   eta_type planned_discharge_location planned_discharge_unlocode  \
# 0     past    LOS ANGELES, CALIFORNIA                      USLAX
# 1     past    LOS ANGELES, CALIFORNIA                      USLAX
# 2   future    LOS ANGELES, CALIFORNIA                      USLAX
# 3   future    LOS ANGELES, CALIFORNIA                      USLAX
# 4     past    LOS ANGELES, CALIFORNIA                      USLAX
#
#               discharge_eta
# 0 2017-11-04 07:12:00+00:00
# 1 2017-11-04 07:12:00+00:00
# 2 2017-11-07 01:00:00+00:00
# 3 2017-11-07 01:00:00+00:00
# 4 2017-11-08 00:07:00+00:00

# %% [markdown]
# Again, convert `milestone_time` to year and day.

# %%
df['year'] = df['milestone_time'].dt.year
df['day'] = df['milestone_time'].dt.dayofyear
# df.drop(['milestone_time'], axis=1, inplace=True)

# %% [markdown]
# Get only the data listed for the year 2017.

# %%
data = df[df['year'] == 2017]

# %%
vessels = data['vessel_id'].unique()
print('Number of vessels: {}'.format(vessels.shape[0]))
# Out:
# Number of vessels: 365

# %% [markdown]
# We have no a more managable number of vessels. Lets pick othe most listed vessel for the year 2017.

# %%
pd.value_counts(data['vessel_id'].values, sort=True).head(1)
# Out:
# 8770    40
# dtype: int64

# %% [markdown]
# Our vessel of choice is `vessel_id` 8770.

# %%
data = data[data['vessel_id'] == 8770].sort_values('day')
data.columns
# Out:
# Index(['container_trip_id', 'milestone_type', 'milestone_time',
#        'milestone_location', 'milestone_unlocode', 'date_received',
#        'ocean_carrier_code', 'port_call_id', 'vessel_id', 'vessel_name',
#        'status_code', 'eta_type', 'planned_discharge_location',
#        'planned_discharge_unlocode', 'discharge_eta', 'year', 'day'],
#       dtype='object')

# %%
# Drop not needed features
features = ['container_trip_id', 'milestone_type', 'milestone_unlocode', 'date_received', 'ocean_carrier_code',
            'port_call_id', 'status_code', 'planned_discharge_unlocode', 'discharge_eta']
data.drop(features, axis=1, inplace=True)

# %%
data
# Out:
#                 milestone_time    milestone_location  vessel_id  vessel_name  \
# 209  2017-09-23 06:24:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1774 2017-09-23 07:05:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1773 2017-09-23 06:05:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1625 2017-09-23 14:22:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1624 2017-09-23 13:22:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1520 2017-09-23 13:12:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1519 2017-09-23 12:12:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1510 2017-09-23 15:45:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1509 2017-09-23 14:45:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1505 2017-09-23 13:36:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1370 2017-09-23 02:50:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1369 2017-09-23 01:50:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1506 2017-09-23 14:36:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 210  2017-09-23 07:24:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1319 2017-09-23 15:17:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1318 2017-09-23 14:17:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 592  2017-09-23 09:25:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 593  2017-09-23 10:25:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 594  2017-10-31 17:55:00+00:00  SINGAPORE, SINGAPORE       8770  APL ENGLAND
# 1776 2017-10-31 20:00:00+00:00  SINGAPORE, SINGAPORE       8770  APL ENGLAND
# 1775 2017-10-31 19:30:00+00:00  SINGAPORE, SINGAPORE       8770  APL ENGLAND
# 211  2017-10-31 11:26:00+00:00  SINGAPORE, SINGAPORE       8770  APL ENGLAND
# 212  2017-10-31 11:56:00+00:00  SINGAPORE, SINGAPORE       8770  APL ENGLAND
# 595  2017-10-31 18:25:00+00:00  SINGAPORE, SINGAPORE       8770  APL ENGLAND
# 1522 2017-11-05 16:44:00+00:00  HONG KONG, HONG KONG       8770  APL ENGLAND
# 1521 2017-11-05 16:14:00+00:00  HONG KONG, HONG KONG       8770  APL ENGLAND
# 1627 2017-11-10 12:52:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1626 2017-11-10 12:22:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1320 2017-11-10 07:00:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1512 2017-11-10 12:04:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1511 2017-11-10 11:34:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1508 2017-11-10 09:40:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1507 2017-11-10 09:10:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1372 2017-11-10 15:14:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1371 2017-11-10 14:44:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 1321 2017-11-10 09:57:00+00:00       SHANGHAI, CHINA       8770  APL ENGLAND
# 2241 2017-12-11 04:23:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1486 2017-12-11 17:19:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 1485 2017-12-11 16:19:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
# 2242 2017-12-11 05:23:00+00:00       MOBILE, ALABAMA       8770  APL ENGLAND
#
#      eta_type planned_discharge_location  year  day
# 209    future     QINGDAO LIUTING, CHINA  2017  266
# 1774   future     QINGDAO LIUTING, CHINA  2017  266
# 1773   future     QINGDAO LIUTING, CHINA  2017  266
# 1625   future  CHONGQING JIANGBEI, CHINA  2017  266
# 1624   future  CHONGQING JIANGBEI, CHINA  2017  266
# 1520   future             HUANGPU, CHINA  2017  266
# 1519   future             HUANGPU, CHINA  2017  266
# 1510   future  CHONGQING JIANGBEI, CHINA  2017  266
# 1509   future  CHONGQING JIANGBEI, CHINA  2017  266
# 1505   future  CHONGQING JIANGBEI, CHINA  2017  266
# 1370   future           ZHENJIANG, CHINA  2017  266
# 1369   future           ZHENJIANG, CHINA  2017  266
# 1506   future  CHONGQING JIANGBEI, CHINA  2017  266
# 210    future     QINGDAO LIUTING, CHINA  2017  266
# 1319   future            SHANGHAI, CHINA  2017  266
# 1318   future            SHANGHAI, CHINA  2017  266
# 592    future     QINGDAO LIUTING, CHINA  2017  266
# 593    future     QINGDAO LIUTING, CHINA  2017  266
# 594    future     QINGDAO LIUTING, CHINA  2017  304
# 1776   future     QINGDAO LIUTING, CHINA  2017  304
# 1775   future     QINGDAO LIUTING, CHINA  2017  304
# 211    future     QINGDAO LIUTING, CHINA  2017  304
# 212    future     QINGDAO LIUTING, CHINA  2017  304
# 595    future     QINGDAO LIUTING, CHINA  2017  304
# 1522   future             HUANGPU, CHINA  2017  309
# 1521   future             HUANGPU, CHINA  2017  309
# 1627   future  CHONGQING JIANGBEI, CHINA  2017  314
# 1626   future  CHONGQING JIANGBEI, CHINA  2017  314
# 1320     past            SHANGHAI, CHINA  2017  314
# 1512   future  CHONGQING JIANGBEI, CHINA  2017  314
# 1511   future  CHONGQING JIANGBEI, CHINA  2017  314
# 1508   future  CHONGQING JIANGBEI, CHINA  2017  314
# 1507   future  CHONGQING JIANGBEI, CHINA  2017  314
# 1372   future           ZHENJIANG, CHINA  2017  314
# 1371   future           ZHENJIANG, CHINA  2017  314
# 1321     past            SHANGHAI, CHINA  2017  314
# 2241   future              NANSHA, CHINA  2017  345
# 1486   future         BUSAN, SOUTH KOREA  2017  345
# 1485   future         BUSAN, SOUTH KOREA  2017  345
# 2242   future              NANSHA, CHINA  2017  345

# %% [markdown]
# Was hoping to see a more interconnected list, meaning that the `planned_discharge_location` will also appear in the `milestone_location` to display how a vessel travels from port to port. It would be interesting - at least for me - to see how a vessel travels and be able to visualize it.

# %% [markdown]
# ## Show how frequent a port is "visited" during a day, month, year.
#
# Let us explore Port of Savannah for the year 2019.

# %%
sav_df = df[(df['year'] == 2019) & (df['milestone_unlocode'] == 'USSAV')]

# Vessels per Year
vessels = sav_df['vessel_id'].unique()
print('Number of vessels per year: {}'.format(vessels.shape[0]))

# Days
days = sav_df['day'].unique()
print('Number of days per year: {}'.format(days.shape[0]))
# Out:
# Number of vessels per year: 157
# Number of days per year: 150

# %% [markdown]
# The `Port of Savannah` were visited so far __150 days__ by __157 vessels__.

# %% [markdown]
# ## eta_tpye: past vs future
#
# Using `eta_type`, show past vs future "tasks" in regards to `milestone_type`

# %%
pd.value_counts(sav_df.eta_type, sort=False)
# Out:
# past       48
# future    452
# Name: eta_type, dtype: int64

# %% [markdown]
# From the `157` vessels so far in 2019 the `Port of Savannah` has 48 `past` tasks listed and 452 still to be done tasks listed as `future`.

# %% [markdown]
# ## Time Series Analyse with Prophet

# %% [markdown]
# Convert `milestone_time` to just date (without hours, minutes, seconds, etc) and save it the `date`.

# %%
df['date'] = pd.to_datetime(df['milestone_time']).dt.date

# %% [markdown]
# Record the delta between `date_received` and `milestone_time` in minutes and store it in `timedelta_in_min`.

# %%
df['time_difference'] = df['date_received'] - df['milestone_time']
df['timedelta_in_min'] = pd.to_timedelta(df['time_difference']).astype('timedelta64[m]').astype(int)
df.drop(['time_difference'], axis=1, inplace=True)
df.head()
# Out:
#    container_trip_id                milestone_type            milestone_time  \
# 0                  1     vessel_arrive_destination 2017-11-02 16:48:00+00:00
# 1                  1  vessel_discharge_destination 2017-11-04 07:12:00+00:00
# 2                  2            vessel_load_origin 2017-10-23 01:18:00+00:00
# 3                  2          vessel_depart_origin 2017-10-23 06:40:00+00:00
# 4                  2     vessel_arrive_destination 2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode             date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA 2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA 2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX 2017-11-08 01:27:00+00:00
#
#   ocean_carrier_code  port_call_id  vessel_id  vessel_name status_code  \
# 0               EGLV     999999999      10034  CAPE KORTIA          VA
# 1               EGLV     999999999      10034  CAPE KORTIA          UV
# 2               EGLV     999999999       7518  EVER LIVELY          AE
# 3               EGLV     999999999       7518  EVER LIVELY          VD
# 4               EGLV     999999999       7518  EVER LIVELY          VA
#
#   eta_type planned_discharge_location planned_discharge_unlocode  \
# 0     past    LOS ANGELES, CALIFORNIA                      USLAX
# 1     past    LOS ANGELES, CALIFORNIA                      USLAX
# 2   future    LOS ANGELES, CALIFORNIA                      USLAX
# 3   future    LOS ANGELES, CALIFORNIA                      USLAX
# 4     past    LOS ANGELES, CALIFORNIA                      USLAX
#
#               discharge_eta  year  day        date  timedelta_in_min
# 0 2017-11-04 07:12:00+00:00  2017  306  2017-11-02              2378
# 1 2017-11-04 07:12:00+00:00  2017  308  2017-11-04                74
# 2 2017-11-07 01:00:00+00:00  2017  296  2017-10-23               433
# 3 2017-11-07 01:00:00+00:00  2017  296  2017-10-23               167
# 4 2017-11-08 00:07:00+00:00  2017  311  2017-11-07               687

# %% [markdown]
# ### How late or early arrives a vessel?

# %%
# Get only arrival data for the year 2019
arrival_df = df[(df['milestone_type'] == 'vessel_arrive_destination') & 
               (df['year'] == 2019)].reset_index(drop=True)

# %%
# All we need for prophet is date and the delta
ts = arrival_df.loc[:, ('date', 'timedelta_in_min')] 
ts = ts.rename(columns={'date': 'ds', 'timedelta_in_min': 'y'})
ts.head()
# Out:
#            ds     y
# 0  2019-01-08  1230
# 1  2019-01-04  3917
# 2  2019-01-02  7764
# 3  2019-01-17  2484
# 4  2019-01-21   384

# %%
ax = ts.set_index('ds').plot(figsize=(16, 8))
ax.set_ylabel('Late/Early in Minutes')
ax.set_xlabel('Date')

plt.show();

# %% [markdown]
# It looks like that the majority of vessels arriving late. Some are as late as 14 days or even up to 100 days. Are theses outliers? Or simply wrong entries in the data. But the majority of the vessels are arrive "only" a day or two late.

# %% [markdown]
# ### Using fbprophet to predict the arrival in the future

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
Model = proph(interval_width=0.95)

# Fit the timeseries into Model
Model.fit(ts)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Use make_future_dataframe with a monthly frequency and periods = 36 for 3 years
future_dates = Model.make_future_dataframe(periods=36, freq='MS')
future_dates.tail()
# Out:
#              ds
# 1978 2022-03-01
# 1979 2022-04-01
# 1980 2022-05-01
# 1981 2022-06-01
# 1982 2022-07-01

# %%
# Predict the values for future dates and take the head of forecast
forecast = Model.predict(future_dates)
forecast.head()
# Out:
#           ds        trend    yhat_lower    yhat_upper  trend_lower  \
# 0 2019-01-01  4394.623589 -15973.900952  21915.756510  4394.623589
# 1 2019-01-01  4394.623589 -14170.887299  22906.284726  4394.623589
# 2 2019-01-01  4394.623589 -13322.375478  21856.185259  4394.623589
# 3 2019-01-02  4364.678916 -12698.924523  22092.126572  4364.678916
# 4 2019-01-02  4364.678916 -15336.285147  21956.999366  4364.678916
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  4394.623589     -377.496056           -377.496056           -377.496056
# 1  4394.623589     -377.496056           -377.496056           -377.496056
# 2  4394.623589     -377.496056           -377.496056           -377.496056
# 3  4364.678916     -200.568569           -200.568569           -200.568569
# 4  4364.678916     -200.568569           -200.568569           -200.568569
#
#        weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 0 -377.496056   -377.496056   -377.496056                   0.0
# 1 -377.496056   -377.496056   -377.496056                   0.0
# 2 -377.496056   -377.496056   -377.496056                   0.0
# 3 -200.568569   -200.568569   -200.568569                   0.0
# 4 -200.568569   -200.568569   -200.568569                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0  4017.127533
# 1                         0.0                         0.0  4017.127533
# 2                         0.0                         0.0  4017.127533
# 3                         0.0                         0.0  4164.110347
# 4                         0.0                         0.0  4164.110347

# %%
# Use prophet's plot function to plot the predictions
Model.plot(forecast, uncertainty=True)

plt.figure(figsize=(16, 8))
plt.show();

# %%
Model.plot_components(forecast)

plt.figure(figsize=(16, 8))
plt.show();

# %% [markdown]
# The overall trend seems downwards, indicating that the vessels in the future will arrive less late with a possibilty being early even. That said, I believe our data is more than skewed with the amount of vessel arriving 2 or more weeks late.
