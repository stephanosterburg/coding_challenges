# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Intro" data-toc-modified-id="Intro-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Intro</a></span></li><li><span><a href="#Load-the-necessary-libraries" data-toc-modified-id="Load-the-necessary-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load the necessary libraries</a></span></li><li><span><a href="#Inspection-+-Cleaning" data-toc-modified-id="Inspection-+-Cleaning-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Inspection + Cleaning</a></span><ul class="toc-item"><li><span><a href="#What-type-data-do-we-have" data-toc-modified-id="What-type-data-do-we-have-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>What type data do we have</a></span></li><li><span><a href="#Data-Types" data-toc-modified-id="Data-Types-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Data Types</a></span></li><li><span><a href="#NaN" data-toc-modified-id="NaN-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>NaN</a></span></li><li><span><a href="#Float-Values" data-toc-modified-id="Float-Values-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Float Values</a></span></li><li><span><a href="#Date" data-toc-modified-id="Date-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Date</a></span></li><li><span><a href="#Duplicates" data-toc-modified-id="Duplicates-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Duplicates</a></span><ul class="toc-item"><li><span><a href="#Find-the-indexies-in-the-pandas-series-which-are" data-toc-modified-id="Find-the-indexies-in-the-pandas-series-which-are-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Find the indexies in the pandas series which are</a></span></li></ul></li><li><span><a href="#Check-dataset" data-toc-modified-id="Check-dataset-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Check dataset</a></span></li><li><span><a href="#How-many-times-is-a-port-listed?" data-toc-modified-id="How-many-times-is-a-port-listed?-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>How many times is a port listed?</a></span></li><li><span><a href="#Create-a-simplified-dataset" data-toc-modified-id="Create-a-simplified-dataset-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Create a simplified dataset</a></span></li><li><span><a href="#How-balanced-is-our-data?" data-toc-modified-id="How-balanced-is-our-data?-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>How balanced is our data?</a></span></li><li><span><a href="#How-connected-is-the-Port-of-Savannah?" data-toc-modified-id="How-connected-is-the-Port-of-Savannah?-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>How connected is the Port of Savannah?</a></span></li><li><span><a href="#How-&quot;connected&quot;-are-the-ports-to-each-other-(based-on-2017)" data-toc-modified-id="How-&quot;connected&quot;-are-the-ports-to-each-other-(based-on-2017)-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>How "connected" are the ports to each other (based on 2017)</a></span><ul class="toc-item"><li><span><a href="#Create-nodes-for-Chord-Diagram" data-toc-modified-id="Create-nodes-for-Chord-Diagram-3.12.1"><span class="toc-item-num">3.12.1&nbsp;&nbsp;</span>Create nodes for Chord Diagram</a></span></li><li><span><a href="#Create-links-for-Chord-Diagram" data-toc-modified-id="Create-links-for-Chord-Diagram-3.12.2"><span class="toc-item-num">3.12.2&nbsp;&nbsp;</span>Create links for Chord Diagram</a></span><ul class="toc-item"><li><span><a href="#Convert-the-ports-to-the-index-numbers-we-have-in-nodes" data-toc-modified-id="Convert-the-ports-to-the-index-numbers-we-have-in-nodes-3.12.2.1"><span class="toc-item-num">3.12.2.1&nbsp;&nbsp;</span>Convert the ports to the index numbers we have in nodes</a></span></li></ul></li><li><span><a href="#Checking-if-everything-is-correct" data-toc-modified-id="Checking-if-everything-is-correct-3.12.3"><span class="toc-item-num">3.12.3&nbsp;&nbsp;</span>Checking if everything is correct</a></span></li><li><span><a href="#Chord-Graph" data-toc-modified-id="Chord-Graph-3.12.4"><span class="toc-item-num">3.12.4&nbsp;&nbsp;</span>Chord Graph</a></span></li><li><span><a href="#I-had-no-clue-you-were-going-to-do-this,-this-is-awesome.-I-would-mention-that-above,-before-you-start-it.-Maybe-put-in-a-picture-of-a-Chord-Graph.-Or-just-have-a-summary-at-the-top-of-explaining-what-your-doing.--" data-toc-modified-id="I-had-no-clue-you-were-going-to-do-this,-this-is-awesome.-I-would-mention-that-above,-before-you-start-it.-Maybe-put-in-a-picture-of-a-Chord-Graph.-Or-just-have-a-summary-at-the-top-of-explaining-what-your-doing.---3.12.5"><span class="toc-item-num">3.12.5&nbsp;&nbsp;</span><span style="color: red">I had no clue you were going to do this, this is awesome. I would mention that above, before you start it. Maybe put in a picture of a Chord Graph. Or just have a summary at the top of explaining what your doing.  </span></a></span></li><li><span><a href="#Create-the-links-for-the-Port-of-Savannah-only" data-toc-modified-id="Create-the-links-for-the-Port-of-Savannah-only-3.12.6"><span class="toc-item-num">3.12.6&nbsp;&nbsp;</span>Create the links for the Port of Savannah only</a></span></li><li><span><a href="#Plot-the-connectivity-of-the-Port-of-Savannah" data-toc-modified-id="Plot-the-connectivity-of-the-Port-of-Savannah-3.12.7"><span class="toc-item-num">3.12.7&nbsp;&nbsp;</span>Plot the connectivity of the Port of Savannah</a></span></li><li><span><a href="#I-don't-know-if-you're-planning-to-do-this,-but-just-redo-this-with-the-port-names-" data-toc-modified-id="I-don't-know-if-you're-planning-to-do-this,-but-just-redo-this-with-the-port-names--3.12.8"><span class="toc-item-num">3.12.8&nbsp;&nbsp;</span><span style="color: red">I don't know if you're planning to do this, but just redo this with the port names </span></a></span></li></ul></li><li><span><a href="#How-many-ports-does-a-vessel-sail-into?" data-toc-modified-id="How-many-ports-does-a-vessel-sail-into?-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>How many ports does a vessel sail into?</a></span></li><li><span><a href="#TODO" data-toc-modified-id="TODO-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>TODO</a></span></li><li><span><a href="#Show-how-frequent-a-port-is-&quot;visited&quot;-during-a-day,-month,-year." data-toc-modified-id="Show-how-frequent-a-port-is-&quot;visited&quot;-during-a-day,-month,-year.-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>Show how frequent a port is "visited" during a day, month, year.</a></span></li><li><span><a href="#eta_tpye:-past-vs-future" data-toc-modified-id="eta_tpye:-past-vs-future-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>eta_tpye: past vs future</a></span></li></ul></li></ul></div>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %%html
# <style type="text/css">
# .rendered_html code  {
#    background-color:#E8E8E8;
#    padding: 3px;
# };
# </style>
# Out:
# <style type="text/css">
# .rendered_html code  {
#    background-color:#E8E8E8;
#    padding: 3px;
# };
# </style>

# %%
```python
aSJJDKS
```
# Out:
#   File "<ipython-input-5-3661d28e6f1d>", line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %%
```bash
for i in *.jpg; do
display $i
done
```
# Out:
#   File "<ipython-input-4-10a213c11419>", line 1
#     ```bash
#     ^
# SyntaxError: invalid syntax

# %%
<div class="alert alert-block alert-info">

<b>Tip:</b> Use blue boxes (alert-info) for tips and notes. 
If it's a note, you don’t have to include the word "Note".

</div>
# Out:
#   File "<ipython-input-2-6d5d53ff78f9>", line 1
#     <div class="alert alert-block alert-info">
#     ^
# SyntaxError: invalid syntax

# %%
from IPython.core.magic import register_cell_magic
from IPython.display import HTML, display

def set_background(color):    
    script = (
        "var cell = this.closest('.jp-CodeCell');"
        "var editor = cell.querySelector('.jp-Editor');"
        "editor.style.background='{}';"
        "this.parentNode.removeChild(this)"
    ).format(color)

    display(HTML('<img src onerror="{}">'.format(script)))
    
@register_cell_magic
def background(color, cell):
    set_background(color)

# %%
# %%background honeydew
# my_important_param = 42
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='honeydew';this.parentNode.removeChild(this)">

# %%
set_background('honeydew')
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='honeydew';this.parentNode.removeChild(this)">

# %%
from IPython.core.magic import register_cell_magic
from IPython.display import HTML, display

@register_cell_magic
def set_background(color, cell=None):
    script = (
        "var cell = this.closest('.jp-CodeCell');"
        "var editor = cell.querySelector('.jp-Editor');"
        "editor.style.background='{}';"
        "this.parentNode.removeChild(this)"
    ).format(color)

    display(HTML('<img src onerror="{}">'.format(script)))

# %%
# %%set_background yellow
# bla = 'bla'*3
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='yellow';this.parentNode.removeChild(this)">

# %% [markdown]
# ---
# # Intro
#
# I am using `holoview` (chord graph and sankey) to display how the ports are connected to each other. Also to see how the Port of Savannah is connected in the year 2019.
#
# ![holoview.png](holoview.png)
#
# __Note__: Unfortunately, bokeh doesn't save correctly, so I am using matplotlib instead. Bokeh would have given us an interactive display where we could "zoom" in and "hover" over the graph to get more detailed informations.
#
# Lastely I am going to use `fbprophet` to do some timeseries analyse towards to end.

# %% [markdown]
# # Load the necessary libraries

# %%
import math
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import holoviews as hv
from holoviews import opts, dim
from bokeh.sampledata.les_mis import data

hv.extension('matplotlib')
hv.output(fig='svg', size=500)
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %% [markdown]
# # Inspection + Cleaning

# %%
df = pd.read_csv('analyst_data_challenge.csv')
df.head()
# Out:
#    container_trip_id                milestone_type             milestone_time  \
# 0                1.0     vessel_arrive_destination  2017-11-02 16:48:00+00:00
# 1                1.0  vessel_discharge_destination  2017-11-04 07:12:00+00:00
# 2                2.0            vessel_load_origin  2017-10-23 01:18:00+00:00
# 3                2.0          vessel_depart_origin  2017-10-23 06:40:00+00:00
# 4                2.0     vessel_arrive_destination  2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode              date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX  2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX  2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA  2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA  2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX  2017-11-08 01:27:00+00:00
#
# ...

# %%
print('Number of Features: {} \nNumber of Observations: {}'.format(df.shape[1], df.shape[0]))
# Out:
# Number of Features: 15
# Number of Observations: 22794

# %% [markdown]
# ## What type data do we have

# %%
df.columns
# Out:
# Index(['container_trip_id', 'milestone_type', 'milestone_time',
#        'milestone_location', 'milestone_unlocode', 'date_received',
#        'ocean_carrier_code', 'port_call_id', 'vessel_id', 'vessel_name',
#        'status_code', 'eta_type', 'planned_discharge_location',
#        'planned_discharge_unlocode', 'discharge_eta'],
#       dtype='object')

# %% [markdown]
# The column definitions are as follows:
#
# + __Container_trip_id__: An integer that uniquely identifies a single container shipment and all the milestones associated with that shipment
# + __Milestone_type__: A string that identifies key events in the shipment life cycle
# + __Milestone_time__: A datetime that indicates the date and time at which the above milestone occurred
# + __Milestone_location__: A string that indicates the name of the location at which the above milestone occurred
# + __Milestone_unlocode__: A 5-character string that is used as a standardized location code (one-to-one with milestone_location)
# + __Date_received__: A datetime that indicates when the milestone update was received (distinct from when the milestone actually occurred)
# + __Ocean_carrier_code__: A 4-character string that uniquely identifies the ocean carrier that is responsible for the shipment
# + __Port_call_id__: An integer that uniquely identifies a vessel stop at a port
# + __Vessel_id__: An integer that uniquely identifies the vessel associated with the current milestone (although sometimes the carrier attaches the incorrect vessel or attaches a future vessel to the current milestone)
# + __Vessel_name__: A string that indicates the name of the vessel associated with the current milestone
# + __Status_code__: A raw code associated with the current milestone
# + __Eta_type__: Either ‘future’ or ‘past’ - indicating whether the discharge_eta (see below) is for a milestone that has already occurred or has yet to occur
# + __Planned_discharge_location__: A string that indicates the name of the location at which the container is scheduled to be discharged (aka unloaded from the vessel at the final port in the container’s journey)
# + __Planned_discharge_unlocode__: A 5-character string that is used as a standardized location code (one-to-one with planned_discharge_location)
# + __Discharge_eta__: A datetime that indicates when the carrier thinks the container will be discharged at the final port in its journey

# %% [markdown]
# ---
# ## Data Types
#
# Making sure that the data types are set correctly, as well as checking for null values and more...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22794 entries, 0 to 22793
# Data columns (total 15 columns):
# container_trip_id             22794 non-null float64
# milestone_type                22794 non-null object
# milestone_time                22794 non-null object
# milestone_location            22794 non-null object
# milestone_unlocode            22794 non-null object
# date_received                 22794 non-null object
# ocean_carrier_code            22788 non-null object
# port_call_id                  15225 non-null float64
# vessel_id                     22794 non-null int64
# vessel_name                   22794 non-null object
# status_code                   22794 non-null object
# eta_type                      22033 non-null object
# planned_discharge_location    22794 non-null object
# planned_discharge_unlocode    22794 non-null object
# discharge_eta                 22553 non-null object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 2.6+ MB

# %% [markdown]
# Some of the data types seem to be wrong, i.e.
# + `container_trip_id` most likely should be not of type `float`
# + `milestone_time` should be of type `datetime`.

# %% [markdown]
# ## NaN
#
# Let us first deal with NULL values.

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isna().sum()
# Out:
# container_trip_id                0
# milestone_type                   0
# milestone_time                   0
# milestone_location               0
# milestone_unlocode               0
# date_received                    0
# ocean_carrier_code               6
# port_call_id                  7569
# vessel_id                        0
# vessel_name                      0
# status_code                      0
# eta_type                       761
# planned_discharge_location       0
# planned_discharge_unlocode       0
# discharge_eta                  241
# dtype: int64

# %% [markdown]
# We have a few features which have no data:
# - `port_call_id`: Considering the size of our dataset and especially, such an important one, is missing too much data (~30%).
# - `eta_type`: With about 3% having no data, we can ignore them and remove the missing entries in order to build our model.
# - `discharge_eta`: With "only" 241 missing data (>1%) we might be able to engineer them, but needs further investigation. Or if they aline with the missing data we are seeing at the `eta_type`, ignore them.
# - `ocean_carrier_code`: We are missing 6 out of 22794. Even though it is an important information to have, to build a model we can neglect the missing entries.

# %% [markdown]
# ## Float Values
#
# We have `container_trip_id` and `port_call_id` which are of type float. Are float numbers like `1.5` are used here as ID's?

# %% [markdown]
# <span style="color:red" >Add docstrings to the functions below specifying what they do, name them based on what they do </span>

# %%
def check_float(n):
    '''
    Checking if the digit after the comma is higher then 0, if that is the case print.
    
    :param n: float value
    :return:  
    '''
    t = str(n).split('.')[1]
    if int(t) > 0:
        print(n)


def check_feature(feature):
    '''
    Iterate over all values in column and check if float value has a number higher then zero. 
    
    :param feature: 
    :return: 
    '''
    for idx, row in df.iterrows():
        if pd.isnull(row[feature]):
            pass
        else:
            check_float(row[feature])

    print('Done')

# %%
df['container_trip_id']
# Out:
# 0           1.0
# 1           1.0
# 2           2.0
# 3           2.0
# 4           2.0
#           ...
# 22789    4611.0
# 22790    4611.0
# 22791    4612.0
# 22792    4613.0
# 22793    4613.0
# Name: container_trip_id, Length: 22794, dtype: float64

# %%
check_feature('container_trip_id')
# Out:
# Done

# %%
df['port_call_id']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 22789     398019.0
# 22790     398019.0
# 22791    1225671.0
# 22792     391909.0
# 22793     391909.0
# Name: port_call_id, Length: 22794, dtype: float64

# %%
check_feature('port_call_id')
# Out:
# Done

# %% [markdown]
# We have no values which are for example 1.5 as an ID, so we can safely convert the two features to type `INT`.

# %%
df['container_trip_id'] = df['container_trip_id'].astype(int)

# %% [markdown]
# Before we convert `port_call_id` to dtype `int`, we need to deal with the `NaN` values. Because of the high number of missing values we shall set them to a special number, i.e. 999999999.

# %%
# Just making sure that 999999999 is not already in the dataset
df['port_call_id'].max()
# Out:
# 1371616.0

# %%
df['port_call_id'] = df['port_call_id'].replace(np.nan, 999999999).astype(int)

# %% [markdown]
# ## Date
#
# We have several features, `milestone_time`, `date_received` and `discharge_eta`, which represent date/time and should be set as such.

# %%
df['milestone_time'] = pd.to_datetime(df['milestone_time'])
df['date_received'] = pd.to_datetime(df['date_received'])
df['discharge_eta'] = pd.to_datetime(df['discharge_eta'])

# %% [markdown]
# ## Duplicates
#
# We want to check for duplicates in our dataset at that point.

# %%
print(any(df['milestone_time'].duplicated()))
# Out:
# True

# %%
dup_df = df['milestone_time'].duplicated()
pd.value_counts(dup_df.values, sort=False)
# Out:
# False    20012
# True      2782
# dtype: int64

# %% [markdown]
# What does that actually mean? Are these real duplicates or is it actually ok to have the same `milestone_time`?

# %% [markdown]
# <span style="color:red" >Add markdown to explain what you're doing below (Investigating a duplicate timestamp) </span>
# ### Find the indexies in the pandas series which are

# %%
# Find element index in pandas series
dup_df[dup_df == True]
# Out:
# 7        True
# 9        True
# 195      True
# 245      True
# 328      True
#          ...
# 22779    True
# 22781    True
# 22783    True
# 22785    True
# 22793    True
# Name: milestone_time, Length: 2782, dtype: bool

# %%
timestamp = df['milestone_time'].iloc[195]
timestamp
# Out:
# Timestamp('2017-12-22 04:00:00+0000', tz='UTC')

# %%
# I don't think you need a groupby here.  Seems like a slice on that timestamp will work fine
ts_df = df.groupby(df['milestone_time'] == timestamp)
ts_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c473ef90ecf4> in <module>
#       1 # I don't think you need a groupby here.  Seems like a slice on that timestamp will work fine
# ----> 2 ts_df = df.groupby(df['milestone_time'] == timestamp)
#       3 ts_df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# `milestone_time` can be the same as long the `milestone_location` is different, i.e. index `90` and `195` have the same `milestone_time` but different a `milestone_location`.
#
# __NOTE__: We still want to make sure that we don't have duplicates in our data.

# %% [markdown]
# ## Check dataset
#
# Just making sure that everything now is cleaned up and now usable.

# %%
df.head()
# Out:
#    container_trip_id                milestone_type            milestone_time  \
# 0                  1     vessel_arrive_destination 2017-11-02 16:48:00+00:00
# 1                  1  vessel_discharge_destination 2017-11-04 07:12:00+00:00
# 2                  2            vessel_load_origin 2017-10-23 01:18:00+00:00
# 3                  2          vessel_depart_origin 2017-10-23 06:40:00+00:00
# 4                  2     vessel_arrive_destination 2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode             date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA 2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA 2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX 2017-11-08 01:27:00+00:00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22794 entries, 0 to 22793
# Data columns (total 15 columns):
# container_trip_id             22794 non-null int64
# milestone_type                22794 non-null object
# milestone_time                22794 non-null datetime64[ns, UTC]
# milestone_location            22794 non-null object
# milestone_unlocode            22794 non-null object
# date_received                 22794 non-null datetime64[ns, UTC]
# ocean_carrier_code            22788 non-null object
# port_call_id                  22794 non-null int64
# vessel_id                     22794 non-null int64
# vessel_name                   22794 non-null object
# status_code                   22794 non-null object
# eta_type                      22033 non-null object
# planned_discharge_location    22794 non-null object
# planned_discharge_unlocode    22794 non-null object
# discharge_eta                 22553 non-null datetime64[ns, UTC]
# ...

# %% [markdown]
# ## How many times is a port listed?

# %%
pd.value_counts(df['milestone_location'].values, sort=True)
# Out:
# SAVANNAH, GEORGIA       1352
# SINGAPORE, SINGAPORE    1245
# BUSAN, SOUTH KOREA      1054
# SHANGHAI, CHINA         1035
# HONG KONG, HONG KONG     864
#                         ...
# BAHRAIN, BAHRAIN           1
# FUQING, CHINA              1
# SHATIAN, CHINA             1
# TAICANG, CHINA             1
# SFAX, TUNISIA              1
# Length: 310, dtype: int64

# %% [markdown]
# Based on the data given the top 5 ports are:
# - SAVANNAH, GEORGIA
# - SINGAPORE, SINGAPORE
# - BUSAN, SOUTH KOREA
# - SHANGHAI, CHINA
# - HONG KONG, HONG KONG
#
# We seem to have an inbalance in our dataset.

# %% [markdown]
# ## Create a simplified dataset
#
# Lets focus on the ports and create from `milestone_time` a `year` and `day` feature.

# %%
# Create a stripped down dataset with only time and port features
milestone_df = df.loc[:, ('milestone_time', 'milestone_unlocode')]
milestone_df.dropna(how='any', inplace=True)

# Convert milestone_time into year and day
milestone_df['year'] = milestone_df['milestone_time'].dt.year
milestone_df['day'] = milestone_df['milestone_time'].dt.dayofyear
milestone_df.drop(['milestone_time'], axis=1, inplace=True)

milestone_df.head()
# Out:
#   milestone_unlocode  year  day
# 0              USLAX  2017  306
# 1              USLAX  2017  308
# 2              CNSHA  2017  296
# 3              CNSHA  2017  296
# 4              USLAX  2017  311

# %% [markdown]
# ## How balanced is our data?
#
# _(Note: This check should come at an earlier stage.)_

# %%
years = milestone_df['year'].unique()
for year in sorted(years):
    print('Year: {} - Number: {}'.format(year, sum((milestone_df['year'] == year))))
# Out:
# Year: 2001 - Number: 1
# Year: 2008 - Number: 7
# Year: 2012 - Number: 5
# Year: 2013 - Number: 10
# Year: 2014 - Number: 9
# Year: 2015 - Number: 35
# Year: 2016 - Number: 18
# Year: 2017 - Number: 1941
# Year: 2018 - Number: 7719
# Year: 2019 - Number: 13049

# %% [markdown]
# We have unfortunately a very unbalanced dataset. Not suprising that we see ports which are only listed once, considering the inbalance in our data. Therefore let us focus on the year 2017 a bit later.

# %%
def plot_by_year(year):
    plt.figure(figsize=(16, 4))
    chart = sns.countplot(
        data=milestone_df[milestone_df['year'] == year],
        x='milestone_unlocode',
        palette='Set1'
    )
    chart.set_xticklabels(chart.get_xticklabels(), 
                          rotation=65, 
                          horizontalalignment='right',
                          fontweight='light',
                          fontsize='xx-small');

# %%
plot_by_year(2017)

# %% [markdown]
# For the year __2017__, `Savannah, Georgia` is the leading port by about 25% (based on the graph above).

# %% [markdown]
# ## How connected is the Port of Savannah?

# %%
# Get Port of Savannah
sav_df = df[df['milestone_unlocode'] == 'USSAV'].reset_index(drop=True)

# Split milestone_time into year and day
sav_df['year'] = sav_df['milestone_time'].dt.year
sav_df['day'] = sav_df['milestone_time'].dt.dayofyear

# Drop not needed features
features = ['container_trip_id', 'milestone_type', 'milestone_time', 'milestone_location', 
            'date_received', 'ocean_carrier_code', 'port_call_id', 'vessel_id', 'vessel_name',
            'status_code', 'planned_discharge_location', 'discharge_eta']
sav_df.drop(features, axis=1, inplace=True)

# Drop all eta_type == past
sav_df.drop(sav_df[sav_df.eta_type == 'past'].index, inplace=True)

sav_df.head()
# Out:
#   milestone_unlocode eta_type planned_discharge_unlocode  year  day
# 0              USSAV   future                      EGALY  2017  240
# 1              USSAV   future                      EGALY  2017  240
# 2              USSAV   future                      DOCAU  2017  357
# 3              USSAV   future                      DOCAU  2017  358
# 4              USSAV   future                      DEBRV  2017  338

# %%
data = pd.value_counts(sav_df['planned_discharge_unlocode'].values, sort=True)
data.head(25)
# Out:
# CNTAO    85
# KRPUS    77
# CNSHA    74
# CNTXG    53
# CNCGU    48
# INNSA    48
# IDJKT    45
# ITLIV    41
# DEBRV    30
# CNNGB    28
# INMUN    26
# IDSUB    26
# RULED    24
# ITNAP    24
# NLRTM    24
# TWKHH    22
# INMAA    22
# COBUN    20
# TRISK    20
# CNXMN    19
# SADMM    18
# CRPMN    18
# INHZA    18
# CNHUA    18
# ESVLC    17
# dtype: int64

# %% [markdown]
# These are the top 25 ports which are highly connected to the Port of Savannah based on number of planned discharge locations in the future (eta_type).

# %% [markdown]
# ## How "connected" are the ports to each other (based on 2017)
#
# We want to look at the relationship between `milestone_location` and `planned_discharge_location` based on `eta_type` if it is set to `future`.

# %%
# Create a stripped down dataset with only time and port features
year_df = df.loc[:, ('milestone_time', 'milestone_unlocode', 'eta_type', 'planned_discharge_unlocode')]
year_df.dropna(how='any', inplace=True)

# Convert milestone_time into year and day
year_df['year'] = year_df['milestone_time'].dt.year
year_df['day'] = year_df['milestone_time'].dt.dayofyear

# Drop feature 'milestone_time' and 'eta_type' == past
year_df.drop(['milestone_time'], axis=1, inplace=True)
year_df.drop(year_df[year_df['eta_type'] == 'past'].index, inplace=True)

# Get only year 2017
year_df = year_df[year_df['year'] == 2017].reset_index(drop=True)

year_df.head()
# Out:
#   milestone_unlocode eta_type planned_discharge_unlocode  year  day
# 0              CNSHA   future                      USLAX  2017  296
# 1              CNSHA   future                      USLAX  2017  296
# 2              CNNGB   future                      CNNGB  2017  245
# 3              CNNGB   future                      CNNGB  2017  245
# 4              USMOB   future                      CNCGU  2017  259

# %% [markdown]
# ### Create nodes for Chord Diagram

# %%
ports = df['milestone_unlocode'].unique()
ports.sort()
nodes = pd.DataFrame({'ports': ports})
nodes['index'] = nodes.index

# %%
t = nodes['index']
nodes.drop(labels=['index'], axis=1, inplace = True)
nodes.insert(0, 'index', t)
nodes.head()
# Out:
#    index  ports
# 0      0  AEAUH
# 1      1  AEJEA
# 2      2  AEKLF
# 3      3  AOLAD
# 4      4  ARBUE

# %% [markdown]
# ### Create links for Chord Diagram

# %%
links = year_df.loc[:, ('milestone_unlocode', 'planned_discharge_unlocode')]
links
# Out:
#      milestone_unlocode planned_discharge_unlocode
# 0                 CNSHA                      USLAX
# 1                 CNSHA                      USLAX
# 2                 CNNGB                      CNNGB
# 3                 CNNGB                      CNNGB
# 4                 USMOB                      CNCGU
# ...                 ...                        ...
# 1156              DEHAM                      RULED
# 1157              RULED                      RULED
# 1158              KRPUS                      CAVAN
# 1159              CAVAN                      CAVAN
# 1160              USTIW                      USTIW
#
# [1161 rows x 2 columns]

# %% [markdown]
# #### Convert the ports to the index numbers we have in nodes

# %%
test = nodes.set_index('index').T.to_dict('list')

# %%
for key, value in test.items():
    links['milestone_unlocode'].mask(links['milestone_unlocode'] == value[0], key, inplace=True)
    links['planned_discharge_unlocode'].mask(links['planned_discharge_unlocode'] == value[0], key, inplace=True)

links.rename(columns={'milestone_unlocode': 'source', 'planned_discharge_unlocode': 'target'}, inplace=True)
links
# Out:
#      source target
# 0        52    282
# 1        52    282
# 2        47     47
# 3        47     47
# 4       285     42
# ...     ...    ...
# 1156     73    231
# 1157    231    231
# 1158    176     32
# 1159     32     32
# 1160    297    297
#
# [1161 rows x 2 columns]

# %% [markdown]
# ### Checking if everything is correct

# %%
links['source'].unique()
# Out:
# array([52, 47, 285, 239, 294, 85, 282, 289, 281, 118, 176, 196, 284, 139,
#        283, 53, 95, 12, 276, 234, 190, 277, 1, 288, 60, 77, 208, 275, 297,
#        56, 268, 156, 138, 233, 179, 207, 90, 28, 57, 86, 210, 274, 290,
#        89, 134, 126, 184, 149, 65, 148, 201, 63, 147, 143, 106, 286, 69,
#        93, 15, 124, 132, 174, 194, 116, 66, 73, 231, 32], dtype=object)

# %%
links['target'].unique()
# Out:
# array([282, 47, 42, 49, 268, 82, 133, 'CNYUY', 48, 139, 45, 159, 56, 57,
#        77, 72, 246, 60, 'CNCKG', 160, 'CNCLJ', 61, 176, 150, 79, 110, 166,
#        190, 134, 196, 252, 102, 32, 'CNCSX', 118, 10, 26, 231, 52, 174, 0,
#        201, 129, 143, 65, 308, 138, 213, 124, 140, 12, 95, 37, 169, 109,
#        11, 39, 132, 142, 270, 128, 71, 136, 126, 149, 43, 148, 46,
#        'CNZHE', 53, 274, 111, 80, 253, 106, 'CNJAX', 165, 69, 168, 171,
#        41, 130, 64, 93, 15, 276, 116, 289, 297], dtype=object)

# %%
for i in links['target'].unique():
    if isinstance(i, str):
        print(len(links[links['target'] == i]))
# Out:
# 2
# 16
# 6
# 3
# 4
# 6

# %% [markdown]
# Let us remove the non-existing ports represented as string from the links.

# %%
for i in links['target'].unique():
    if isinstance(i, str):
        links.drop(links[links['target'] == i].index, inplace=True)

links.head()
# Out:
#   source target
# 0     52    282
# 1     52    282
# 2     47     47
# 3     47     47
# 4    285     42

# %% [markdown]
# ### Chord Graph
#
# Display the interconnectivity of the port in the year 2017.
#
# __Note__: The below graph is displayed as matlibplot instead of bokeh. Preferably I wanted to use the bokeh representation, but had issues with not displaying when opening the notebook.

# %% [markdown]
# ### <span style="color:red" >I had no clue you were going to do this, this is awesome. I would mention that above, before you start it. Maybe put in a picture of a Chord Graph. Or just have a summary at the top of explaining what your doing.  </span>

# %%
# For holoview to work, we add node labels and other information 
# we construct a Dataset with a key dimension of node indices.
nodes = hv.Dataset(nodes, 'index')

# %%
chord = hv.Chord((links, nodes)).select(value=(5, None))
chord.opts(
    opts.Chord(cmap='Category20', 
               edge_cmap='Category20', 
               edge_color=dim('source').str(), 
               labels='ports', 
               node_color=dim('index').str()))
# Out:
# :Chord   [source,target]

# %% [markdown]
# We can see on the right side of the graph `USSAV (Port of Savannah)` and see how connected the port is to the rest of the world in 2017.

# %% [markdown]
# ### Create the links for the Port of Savannah only

# %%
sav_links = year_df.loc[:, ('milestone_unlocode', 'planned_discharge_unlocode')] 
sav_links = sav_links.drop(sav_links[sav_links.milestone_unlocode != 'USSAV'].index)

# %% [markdown]
# Create a dataframe with source port (`USSAV`) and its `planned_discharge_unlocode` as `target` and the number of times they appear.

# %%
# Count values in sav_links
result = sav_links.apply(pd.value_counts).fillna(0)
# Convert index t ocolumn
result.reset_index(level=0, inplace=True)
# Drop everything which is not USSAV
result = result[result['index'] != 'USSAV']
result.drop(['milestone_unlocode'], axis=1, inplace=True)
# Rename columns
result.rename(columns={'index': 'target', 'planned_discharge_unlocode': 'value'}, inplace=True)
result['source'] = 'USSAV'
# Reorder columns
tmp = result['source']
result.drop(labels=['source'], axis=1, inplace = True)
result.insert(0, 'source', tmp)

result.head()
# Out:
#   source target  value
# 0  USSAV  AEAUH    2.0
# 1  USSAV  AUSYD    2.0
# 2  USSAV  BDCGP    2.0
# 3  USSAV  BEANR    2.0
# 4  USSAV  BRSSZ    2.0

# %%
print('Number of planned discharge ports: {}'.format(result.shape[0]))
# Out:
# Number of planned discharge ports: 42

# %% [markdown]
# ### Plot the connectivity of the Port of Savannah

# %%
sankey = hv.Sankey(result, label='Port of Savannah')
sankey.opts(label_position='left', edge_color='target', node_color='index', cmap='tab20')
# Out:
# :Sankey   [source,target]   (value)

# %% [markdown]
# The `Port of Savannah` has `161` vessels leaving its port to `42` ports. The top 3 port are `CNTXG`, `ITLIV` and `KRPUS`.
#
# __Note__: Should use the actual port names instead their code.

# %% [markdown]
# ### <span style="color:red" >I don't know if you're planning to do this, but just redo this with the port names </span>

# %% [markdown]
# ## How many ports does a vessel sail into?

# %%
vessels = df['vessel_id'].unique()
print('Number of vessels: {}'.format(vessels.shape[0]))
# Out:
# Number of vessels: 2076

# %% [markdown]
# We have over 2000 vessels listed in our data. Let us focus again only on the year 2017 and pick a vessel from that year.

# %%
df.head()
# Out:
#    container_trip_id                milestone_type            milestone_time  \
# 0                  1     vessel_arrive_destination 2017-11-02 16:48:00+00:00
# 1                  1  vessel_discharge_destination 2017-11-04 07:12:00+00:00
# 2                  2            vessel_load_origin 2017-10-23 01:18:00+00:00
# 3                  2          vessel_depart_origin 2017-10-23 06:40:00+00:00
# 4                  2     vessel_arrive_destination 2017-11-07 14:00:00+00:00
#
#         milestone_location milestone_unlocode             date_received  \
# 0  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 1  LOS ANGELES, CALIFORNIA              USLAX 2017-11-04 08:26:00+00:00
# 2          SHANGHAI, CHINA              CNSHA 2017-10-23 08:31:00+00:00
# 3          SHANGHAI, CHINA              CNSHA 2017-10-23 09:27:00+00:00
# 4  LOS ANGELES, CALIFORNIA              USLAX 2017-11-08 01:27:00+00:00
#
# ...

# %% [markdown]
# Again, convert `milestone_time` to year and day.

# %%
df['year'] = df['milestone_time'].dt.year
df['day'] = df['milestone_time'].dt.dayofyear
df.drop(['milestone_time'], axis=1, inplace=True)

# %% [markdown]
# Get only the data listed for the year 2017.

# %%
data = df[df['year'] == 2017]

# %%
vessels = data['vessel_id'].unique()
print('Number of vessels: {}'.format(vessels.shape[0]))
# Out:
# Number of vessels: 365

# %% [markdown]
# We have no a more managable number of vessels. Lets pick othe most listed vessel for the year 2017.

# %%
pd.value_counts(data['vessel_id'].values, sort=True).head(1)
# Out:
# 8770    40
# dtype: int64

# %% [markdown]
# Our vessel of choice is `vessel_id` 8770.

# %%
data = data[data['vessel_id'] == 8770].sort_values('day')
data.columns
# Out:
# Index(['container_trip_id', 'milestone_type', 'milestone_location',
#        'milestone_unlocode', 'date_received', 'ocean_carrier_code',
#        'port_call_id', 'vessel_id', 'vessel_name', 'status_code', 'eta_type',
#        'planned_discharge_location', 'planned_discharge_unlocode',
#        'discharge_eta', 'year', 'day'],
#       dtype='object')

# %%
# Drop not needed features
features = ['container_trip_id', 'milestone_type', 'milestone_unlocode', 'date_received', 'ocean_carrier_code',
            'port_call_id', 'status_code', 'planned_discharge_unlocode', 'discharge_eta']
data.drop(features, axis=1, inplace=True)

# %%
data
# Out:
#         milestone_location  vessel_id  vessel_name eta_type  \
# 209        MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1774       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1773       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1625       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1624       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1520       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1519       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1510       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1509       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1505       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1370       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1369       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1506       MOBILE, ALABAMA       8770  APL ENGLAND   future
# 210        MOBILE, ALABAMA       8770  APL ENGLAND   future
# 1319       MOBILE, ALABAMA       8770  APL ENGLAND   future
# ...

# %% [markdown]
# Was hoping to see a more interconnected list, meaning that the `planned_discharge_location` will also appear in the `milestone_location` to display how a vessel travels from port to port. It would be interesting - at least for me - to see how a vessel travels and be able to visualize it.

# %% [markdown]
# ---
#
# ## TODO
#
# 1. ~~Show how frequent a port is "visited" during a day, month, year.~~
# 2. ~~Using `eta_type`, show past vs future "tasks" in regards to `milestone_type`.~~
# 3. With the Chord diagram we can see how interconnected all ports are, might be helpful to also show it as a heatmap.
# 4. In regards to `milestone_type` it would be of interest to show show much time is spend between all the different types, i.e. vessel_arrive_destination, vessel_discharge_destination, vessel_load_origin, etc.
# 5. Not sure if that is with the given dataset possible, but it would great to know at what capacity at vessel is sailing from port to port.

# %% [markdown]
# ---
#
# ## Show how frequent a port is "visited" during a day, month, year.
#
# Let us explore Port of Savannah for the year 2019.

# %%
sav_df = df[(df['year'] == 2019) & (df['milestone_unlocode'] == 'USSAV')]

# Vessels per Year
vessels = sav_df['vessel_id'].unique()
print('Number of vessels per year: {}'.format(vessels.shape[0]))

# Days
days = sav_df['day'].unique()
print('Number of days per year: {}'.format(days.shape[0]))
# Out:
# Number of vessels per year: 157
# Number of days per year: 150

# %% [markdown]
# The `Port of Savannah` were visited so far __150 days__ by __157 vessels__.

# %% [markdown]
# ## eta_tpye: past vs future

# %%
pd.value_counts(sav_df.eta_type, sort=False)
# Out:
# past       48
# future    452
# Name: eta_type, dtype: int64

# %% [markdown]
# From the `157` vessels so far in 2019 the `Port of Savannah` has 48 `past` tasks listed and 452 still to be done tasks listed as `future`.
